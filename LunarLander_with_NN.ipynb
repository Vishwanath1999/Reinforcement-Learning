# %% [markdown]
# # 1. Import Dependancies

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Test With OpenAI Gym

# %%
env = gym.make('LunarLander-v2')

# %%
episodes = 10

for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
     
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:{}, Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1, Score:-164.22510335560554
# Episode:2, Score:-243.73790871950425
# Episode:3, Score:-102.81245368021541
# Episode:4, Score:-233.43212172293656
# Episode:5, Score:-9.101003166181954
# Episode:6, Score:-129.3169348013842
# Episode:7, Score:-401.9876867921636
# Episode:8, Score:-316.7486677697133
# Episode:9, Score:-257.3209544401666
# Episode:10, Score:-284.08954671599804

# %%
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=2e5)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 460  |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 378         |
# |    iterations           | 2           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007976068 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0142     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 468         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00513    |
# |    value_loss           | 1.54e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 358         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004002149 |
# |    clip_fraction        | 0.00981     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.0077     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 386         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 943         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009359569 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -0.0178     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 488         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00968    |
# |    value_loss           | 671         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009479948 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -9.94e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 220         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00752    |
# |    value_loss           | 486         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015786607 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.000913   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 154         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00962    |
# |    value_loss           | 404         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 7           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016059514 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -0.035      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 112         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00318    |
# |    value_loss           | 534         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 339         |
# |    iterations           | 8           |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015318811 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.00993     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 167         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 381         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 337         |
# |    iterations           | 9           |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014575735 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.335      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 156         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00624    |
# |    value_loss           | 257         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 10          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017638283 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.0205      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 144         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00755    |
# |    value_loss           | 436         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 11          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012456317 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.0758      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 241         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.008      |
# |    value_loss           | 451         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 333        |
# |    iterations           | 12         |
# |    time_elapsed         | 73         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00990105 |
# |    clip_fraction        | 0.0535     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.0456     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 157        |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00674   |
# |    value_loss           | 484        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 13          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019284103 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 68.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 131         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 14          |
# |    time_elapsed         | 86          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017525885 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 82.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 205         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 15           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0075529004 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 305          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00571     |
# |    value_loss           | 464          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 16          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007353688 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.332       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00476    |
# |    value_loss           | 318         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 322         |
# |    iterations           | 17          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013965709 |
# |    clip_fraction        | 0.0816      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.354       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00933    |
# |    value_loss           | 187         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 320         |
# |    iterations           | 18          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.005613573 |
# |    clip_fraction        | 0.0166      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.369       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.3        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 212         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 320          |
# |    iterations           | 19           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0065601086 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.632        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38.4         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00496     |
# |    value_loss           | 88.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 20          |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007153481 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 80.9        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00588    |
# |    value_loss           | 223         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 313         |
# |    iterations           | 21          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.017186105 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 170         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 311          |
# |    iterations           | 22           |
# |    time_elapsed         | 144          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0035934553 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.75         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.6         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00572     |
# |    value_loss           | 90.9         |
# ------------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 309       |
# |    iterations           | 23        |
# |    time_elapsed         | 152       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0066313 |
# |    clip_fraction        | 0.0354    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.1      |
# |    explained_variance   | 0.547     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 168       |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -0.00492  |
# |    value_loss           | 240       |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 308         |
# |    iterations           | 24          |
# |    time_elapsed         | 159         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007282718 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0072     |
# |    value_loss           | 121         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 25          |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.010147271 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 106         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00711    |
# |    value_loss           | 285         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 306         |
# |    iterations           | 26          |
# |    time_elapsed         | 173         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015076536 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00607    |
# |    value_loss           | 93.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 27          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008113836 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.71        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 122         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 302         |
# |    iterations           | 28          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.008478712 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00869    |
# |    value_loss           | 49          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 29           |
# |    time_elapsed         | 197          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0074268845 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.774        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00662     |
# |    value_loss           | 87.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 298         |
# |    iterations           | 30          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.015258489 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 60.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 295         |
# |    iterations           | 31          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.015698185 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00974    |
# |    value_loss           | 39.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 294         |
# |    iterations           | 32          |
# |    time_elapsed         | 222         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005969978 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.91        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00641    |
# |    value_loss           | 20          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 33          |
# |    time_elapsed         | 230         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.010647345 |
# |    clip_fraction        | 0.0778      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 32          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 291         |
# |    iterations           | 34          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007997035 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.927      |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.89        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00632    |
# |    value_loss           | 36          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 35          |
# |    time_elapsed         | 246         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009007468 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.37        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 15.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 36          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.006470663 |
# |    clip_fraction        | 0.0176      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.589       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 77.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 37          |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.011466964 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.988      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.008      |
# |    value_loss           | 54.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 38          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012266191 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10          |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 37.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 289         |
# |    iterations           | 39          |
# |    time_elapsed         | 275         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008348528 |
# |    clip_fraction        | 0.0377      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00291    |
# |    value_loss           | 99.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 40          |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.018230982 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.746       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 280         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 138         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 41          |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.026393909 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.54        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 286         |
# |    iterations           | 42          |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011868472 |
# |    clip_fraction        | 0.0943      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.726       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 103         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 286          |
# |    iterations           | 43           |
# |    time_elapsed         | 307          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0022620307 |
# |    clip_fraction        | 0.0669       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.8         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00574     |
# |    value_loss           | 46           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 285         |
# |    iterations           | 44          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008150196 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00404    |
# |    value_loss           | 79.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 45          |
# |    time_elapsed         | 323         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.016498271 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.57        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 46          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012986458 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.896      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00287    |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 47          |
# |    time_elapsed         | 339         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007889336 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.11        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00403    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 48          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.002960422 |
# |    clip_fraction        | 0.0316      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.86       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 102         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 49          |
# |    time_elapsed         | 354         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006057835 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.685       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 98.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 282        |
# |    iterations           | 50         |
# |    time_elapsed         | 362        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.01779909 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.828     |
# |    explained_variance   | 0.784      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.66       |
# |    n_updates            | 490        |
# |    policy_gradient_loss | -0.00694   |
# |    value_loss           | 61.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 282         |
# |    iterations           | 51          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.005572658 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.803      |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.42        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 7.95        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 52           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0019105863 |
# |    clip_fraction        | 0.0385       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.92        |
# |    explained_variance   | 0.689        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45.7         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 48.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 53          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.009528368 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 117         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00528    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 54          |
# |    time_elapsed         | 392         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.011400564 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.37        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 7.68        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 55           |
# |    time_elapsed         | 400          |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0007738222 |
# |    clip_fraction        | 0.0021       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.906       |
# |    explained_variance   | 0.487        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 43.5         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 174          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 56          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.010602454 |
# |    clip_fraction        | 0.0829      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | 0.694       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.7        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00512    |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 57          |
# |    time_elapsed         | 415         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.014092001 |
# |    clip_fraction        | 0.0927      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.67        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.00598    |
# |    value_loss           | 7.89        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 281         |
# |    iterations           | 58          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.008253061 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67          |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 183         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 59          |
# |    time_elapsed         | 430         |
# |    total_timesteps      | 120832      |
# | train/                  |             |
# |    approx_kl            | 0.008967391 |
# |    clip_fraction        | 0.0679      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 74.3        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 49.9        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 280        |
# |    iterations           | 60         |
# |    time_elapsed         | 437        |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.00858908 |
# |    clip_fraction        | 0.0694     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.807     |
# |    explained_variance   | 0.719      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.1       |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.00373   |
# |    value_loss           | 90.2       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 280          |
# |    iterations           | 61           |
# |    time_elapsed         | 445          |
# |    total_timesteps      | 124928       |
# | train/                  |              |
# |    approx_kl            | 0.0062282267 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.642        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.4         |
# |    n_updates            | 600          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 148          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 62          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.005696577 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 72.4        |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 42          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 280         |
# |    iterations           | 63          |
# |    time_elapsed         | 459         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.009529369 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.764      |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41          |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00292    |
# |    value_loss           | 77.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 281          |
# |    iterations           | 64           |
# |    time_elapsed         | 466          |
# |    total_timesteps      | 131072       |
# | train/                  |              |
# |    approx_kl            | 0.0064579113 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 154          |
# |    n_updates            | 630          |
# |    policy_gradient_loss | -0.0041      |
# |    value_loss           | 235          |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# ...
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 78          |
# |    time_elapsed         | 563         |
# |    total_timesteps      | 159744      |
# | train/                  |             |
# |    approx_kl            | 0.011871442 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 0.809       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.3        |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.0034     |
# |    value_loss           | 93.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 79          |
# |    time_elapsed         | 571         |
# |    total_timesteps      | 161792      |
# | train/                  |             |
# |    approx_kl            | 0.005468907 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.965       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.87        |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -6.13e-05   |
# |    value_loss           | 10.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 80           |
# |    time_elapsed         | 578          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0059610773 |
# |    clip_fraction        | 0.0274       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.17         |
# |    n_updates            | 790          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 76           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 81           |
# |    time_elapsed         | 585          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0042196442 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.737        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.2         |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 158          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 82          |
# |    time_elapsed         | 592         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.006184484 |
# |    clip_fraction        | 0.0396      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.747      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.6        |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 83          |
# |    time_elapsed         | 599         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.007446592 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 159         |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00472    |
# |    value_loss           | 164         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 84           |
# |    time_elapsed         | 606          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0038300338 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.724       |
# |    explained_variance   | 0.802        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.72         |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0026      |
# |    value_loss           | 31.6         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 85          |
# |    time_elapsed         | 614         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.003573415 |
# |    clip_fraction        | 0.04        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.719      |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 169         |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 214         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 86           |
# |    time_elapsed         | 621          |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0029148373 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.726       |
# |    explained_variance   | 0.85         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.5         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 57           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 87           |
# |    time_elapsed         | 628          |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0011268766 |
# |    clip_fraction        | 0.0496       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.829       |
# |    explained_variance   | 0.784        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.7         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 65.3         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 283           |
# |    iterations           | 88            |
# |    time_elapsed         | 636           |
# |    total_timesteps      | 180224        |
# | train/                  |               |
# |    approx_kl            | 0.00015170919 |
# |    clip_fraction        | 0.0429        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.782        |
# |    explained_variance   | 0.723         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14.2          |
# |    n_updates            | 870           |
# |    policy_gradient_loss | -0.00212      |
# |    value_loss           | 96.1          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 89           |
# |    time_elapsed         | 642          |
# |    total_timesteps      | 182272       |
# | train/                  |              |
# |    approx_kl            | 0.0015774121 |
# |    clip_fraction        | 0.0569       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.813       |
# |    explained_variance   | 0.669        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 137          |
# |    n_updates            | 880          |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 186          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 90          |
# |    time_elapsed         | 650         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.008839612 |
# |    clip_fraction        | 0.0294      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.7        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 179         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 91          |
# |    time_elapsed         | 657         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.012335488 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 131         |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 194         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 283          |
# |    iterations           | 92           |
# |    time_elapsed         | 664          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0033713877 |
# |    clip_fraction        | 0.0298       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63.9         |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 210          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 93          |
# |    time_elapsed         | 671         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.007073516 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0015     |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 283         |
# |    iterations           | 94          |
# |    time_elapsed         | 677         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.013343455 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.545       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.4        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 240         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 95          |
# |    time_elapsed         | 684         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.011582417 |
# |    clip_fraction        | 0.082       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00538    |
# |    value_loss           | 81.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 96          |
# |    time_elapsed         | 691         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.013649482 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.704      |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 102         |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00315    |
# |    value_loss           | 113         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 284         |
# |    iterations           | 97          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.008703482 |
# |    clip_fraction        | 0.039       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 210         |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 181         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 284        |
# |    iterations           | 98         |
# |    time_elapsed         | 705        |
# |    total_timesteps      | 200704     |
# | train/                  |            |
# |    approx_kl            | 0.00530662 |
# |    clip_fraction        | 0.0888     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.729     |
# |    explained_variance   | 0.736      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 49.4       |
# |    n_updates            | 970        |
# |    policy_gradient_loss | -0.00372   |
# |    value_loss           | 136        |
# ----------------------------------------

# %%
episodes = 30

for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
     
    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
        
    print('Episode:{}, Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1, Score:[252.15521]
# Episode:2, Score:[236.28642]
# Episode:3, Score:[232.23714]
# Episode:4, Score:[225.61382]
# Episode:5, Score:[242.93858]
# Episode:6, Score:[225.62878]
# Episode:7, Score:[-9.903587]
# Episode:8, Score:[267.40475]
# Episode:9, Score:[2.9974976]
# Episode:10, Score:[235.37297]
# Episode:11, Score:[247.68985]
# Episode:12, Score:[228.8557]
# Episode:13, Score:[224.39693]
# Episode:14, Score:[218.51144]
# Episode:15, Score:[256.67975]
# Episode:16, Score:[262.29413]
# Episode:17, Score:[224.5441]
# Episode:18, Score:[234.46313]
# Episode:19, Score:[223.08429]
# Episode:20, Score:[216.74881]
# Episode:21, Score:[222.3739]
# Episode:22, Score:[241.42766]
# Episode:23, Score:[-16.604622]
# Episode:24, Score:[225.36937]
# Episode:25, Score:[239.84679]
# Episode:26, Score:[-19.80709]
# Episode:27, Score:[228.39507]
# Episode:28, Score:[231.7989]
# Episode:29, Score:[283.917]
# Episode:30, Score:[240.78053]
